# %%
# !pip install google_play_scraper
# Out:
# Collecting google_play_scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.1 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google_play_scraper
# Successfully installed google_play_scraper-1.2.7

# %%
from google_play_scraper import reviews, Sort
import pandas as pd

# %%
app = "com.amazon.mShop.android.shopping"


data, _ = reviews(
    app,
    lang='en',
    country='us',
    sort=Sort.NEWEST,
    count=100
)

# %%
df = pd.DataFrame(data)[['userName', 'score', 'content', 'at']]
df.columns = ['Customer Name', 'Rating', 'Review', 'Date']

# %%
df['Tag'] = df['Rating'].apply(lambda x: 'Positive' if x >= 4 else 'Neutral' if x == 3 else 'Negative')

# %%
filename = f"{app}_reviews.csv"
df.to_csv(filename, index=False)

# %%
df.head()
# Out:
#      Customer Name  Rating                                             Review  \
# 0   Annetta Givens       5                                            love it
# 1  Anthony Jackson       5                                               good
# 2  Raíssa Maniezzo       1  The absolute worst! I've been trying to contac...
# 3            James       1  If I could give a 0 rating I would they say th...
# 4           J Pest       1  fix your problem. if you can't tell me what th...
#
#                  Date       Tag
# 0 2025-05-08 15:53:27  Positive
# 1 2025-05-08 15:38:44  Positive
# 2 2025-05-08 15:14:21  Negative
# 3 2025-05-08 15:11:49  Negative
# 4 2025-05-08 15:06:22  Negative
